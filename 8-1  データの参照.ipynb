# %% [markdown]
# ### 8-1-1　文字の扱いについて

# %% [markdown]
# ・キーワードの大文字と小文字は区別しない<br>
# ・文字や日付情報はシングルクォートで囲む<br>
# <br>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ※カラム名に、'  'は不要

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 8-1-2　列（カラム）、テーブル、検索条件の指定

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 8-1-3　ORDER BY

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# order byは左から順に処理される。1つ目の並べ替えで同じ順のものがあれば、2つ目の並べ替えが適用される。

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 8-1-4　LIMIT と OFFSET

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 抽出されたデータの1件目をスキップし、2件目以降から3個のデータを取り出している。

# %% [markdown]
# ### 8-1-5　DISTINCT

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# on  (列名) を省略すれば、重複除去および抽出対象が年齢となり<br>
# on（年齢）* と指定すれば、年齢に対してのみ重複除去して、全列を抽出する。
#
# つまり、on (列名) を省略すると、重複除去・抽出の両方の対象となる。
#
# また、DISTINCT ONでの実行結果はソートされる。<br>
# ORDER BYを併用した場合は、ORDER BYが優先となる。

# %% [markdown]
# ### 8-1-6　GROUP BY と Having

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 集約関数を使用すると、列名を複数指定できる。

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 処理の順番：Where → GROUP BY → HAVING

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 部署でグループ化してから、最高年齢が30歳以下の部署に絞り、部署とsum(年齢)を取り出している。

# %% [markdown]
# ### 8-1-7　副問い合わせ

# %% [markdown]
# SELECT（問い合わせ）→ サブセレクトと呼ばれる。

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ※副問い合わせの結果が2件以上になると、エラーとなるので注意すること。

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 問い合わせ対象のテーブルが2つあるため、抽出結果も2つ分となる。

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 副問い合わせが2個以上ある場合には、エイリアス（as でつける別名）が必要となる。

# %% [markdown]
# ### 8-1-7　IN と NOT IN

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 8-1-9　ANY

# %% [markdown]
# IN と同じ働きだが、副問い合わせの結果が必ず1列となる。

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 8-1-10　BETWEEN

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 8-1-11　結合

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### INNER JOIN

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# NATURALを用いた場合、結合に使用された列は一番左の列としてまとめられる。

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### CROSS JOIN

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 右から2番目の部署idを見ると、全ての組み合わせが結合されていることが分かりやすい。

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### LEFT OUTER JOIN

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### RIGHT OUTER JOIN

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### FULL OUTER JOIN

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 8-1-12　EXISTS と NOT EXISTS

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# EXISTSは行を返すかどうかの指定しかしないため、副問い合わせのselectでは何を指定しても問題ない。<br>
# 副問い合わせ内の条件に合致するものがあれば、usersの中から抽出するだけである。

# %% [markdown]
# 逆にNOT EXISTSは、条件に合致しないものを、usersの中から抽出する。

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 8-1-13　UNION／EXCEPT／INTERSECT

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# UNIONした結果に対して、ORDER BYを実行している。

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ALLを付与すると、重複行がそのまま出力される。

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# EXCEPTは、2つのテーブルのうち、左側のテーブルにあるデータだけを抽出する。

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# INTERSECTは、2つのテーブルのうち、両方とも存在するデータのみを抽出する。

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# UNION／EXCEPT／INTERSECTを同時に使用した場合、最優先となるのはINTERSECTとなり<br>
# それ以外は左から順に処理される。
