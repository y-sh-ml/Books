# %% [markdown]
# ## 8-7　ビュー

# %% [markdown]
# ビューとは、SELECT文の結果を定義したものである。

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 下記では、tblテーブルのlevel2以下のデータを出力結果として定義している。

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ビューの削除を行う。

# %% [markdown]
# ![image.png](attachment:image.png)
