# %%
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots()

x = [1, 2, 3]
y = [10, 2, 3]

labels = ['spam', 'ham', 'egg']
ax.barh(x, y, tick_label = labels)

plt.show()

# %%
fig, ax = plt.subplots()

x = [1, 2, 3]
y1 = [10, 2, 3]
y2 = [5, 3, 6]

labels = ['spam', 'ham', 'egg']
width = 0.4

# 棒の幅を指定
ax.bar(x, y1, width = width, tick_label = labels, label = 'y1')

# 中心値をずらす
x2 = [num + width for num in x]

# 棒の幅を指定
ax.bar(x2, y2, width = width, label = 'y2')

ax.legend()

plt.show()

# %%
fig, ax = plt.subplots()

x = [1, 2, 3]
y1 = [10, 2, 3]
y2 = [5, 3, 6]

labels =['spam', 'ham', 'egg']

# y1,y2 から値を取り出して、和を取る
y_total = [num1 + num2 for num1, num2 in zip(y1, y2)]

ax.bar(x, y_total, tick_label = labels, label = 'y1')

# 積み上げグラフの下にくるものを指定する
ax.bar(x, y2, label = 'y2')

ax.legend()

plt.show()

# %%
import numpy as np

mu = 100
sigma = 15

x = np.random.normal(mu, sigma, 1000)

fig, ax = plt.subplots()

n, bins, patches = ax.hist(x)

plt.show()

# %%
for i, num in enumerate(n):
    print('{:.2f} - {:.2f}:{}'.format(bins[i], bins[i + 1], num))
# Out:
# 46.33 - 56.65:3.0
# 56.65 - 66.98:10.0
# 66.98 - 77.30:52.0
# 77.30 - 87.63:142.0
# 87.63 - 97.95:227.0
# 97.95 - 108.27:259.0
# 108.27 - 118.60:184.0
# 118.60 - 128.92:94.0
# 128.92 - 139.25:24.0
# 139.25 - 149.57:5.0

# %%
n.shape
# Out:
# (10,)

# %%
mu = 100
x0 = np.random.normal(mu, 20, 1000)

x1 = np.random.normal(mu, 15, 1000)
x2 = np.random.normal(mu, 10, 1000)

fig, ax = plt.subplots()

labels = ['x0', 'x1', 'x2']

ax.hist((x0, x1, x2), label = labels)

plt.show()

# 棒グラフは中心値を横にずらして描写するが、ヒストグラムは自動的に横に並んでくれる

# %%
# ヒストグラムの積み上げ型は、stacked を使用する

fig, ax = plt.subplots()

labels = ['x0', 'x1', 'x2']

# あとから下に来る方を書く
ax.hist((x0, x1, x2), label= labels, stacked = True)
ax.legend()

plt.show()

# %%
x0 = np.random.normal(0, 10, 500)
x1 = np.random.normal(0, 15, 500)
x2 = np.random.normal(0, 20, 500)

fig, ax = plt.subplots()

labels = ['x0', 'x1', 'x2']
ax.boxplot((x0, x1, x2), labels = labels, vert = False)

plt.show()

# %%
labels = ['spam', 'ham', 'egg']

x = [10, 3, 1]

explode = [0, 0.2, 1]

fig, ax = plt.subplots()

ax.pie(x, labels = labels, startangle = 90, counterclock = False, shadow = True, autopct = '%1.2f%%', explode = explode)

ax.axis('equal')

plt.show()
