# %% [markdown]
# ## 8.3　Attention の評価

# %%
import os
import sys
import numpy as np

# %%
os.chdir('/Users/yuta.shimizu/Downloads/ML/deep-learning-from-scratch-2-master/ch08')
sys.path.append(os.pardir)

# %% [markdown]
# ### 8.3.2　Attention 付き seq2seq の学習

# %%
from dataset import sequence
from common.trainer import Trainer
from ch07.seq2seq import Seq2seq
from common.optimizer import Adam
from common.util import eval_seq2seq
from attention_seq2seq import AttentionSeq2seq

# %%
(x_train, t_train), (x_test, t_test) = sequence.load_data('date.txt')
char_to_id, id_to_char = sequence.get_vocab()
x_train, x_test = x_train[:, ::-1], x_test[:, ::-1]

# %%
vocab_size = len(char_to_id)
wordvec_size = 16
hidden_size = 256
batch_size = 128
max_epoch = 10
max_grad = 5.0
print(vocab_size)
# Out:
# 59

# %%
model = AttentionSeq2seq(vocab_size, wordvec_size, hidden_size)
optimizer = Adam()
trainer = Trainer(model, optimizer)

acc_list = []
for epoch in range(max_epoch):
    trainer.fit(x_train, t_train, max_epoch=1, batch_size=batch_size, max_grad=max_grad)
    
    correct_num = 0
    for i in range(len(x_test)):
        question, correct = x_test[[i]], t_test[[i]]
        verbose = i < 10
        correct_num += eval_seq2seq(model, question, correct, id_to_char, verbose, is_reverse=True)
        
    acc = float(correct_num) / len(x_test)
    acc_list.append(acc)
    print('val acc %.3f%%' % (acc * 100))

model.save_params()

x = np.arange(len(acc_list))
plt.plot(x, acc_list, marker='o')
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.ylim(-0.05, 1.05)
plt.show()
# Out:
# | epoch 1 |  iter 1 / 351 | time 0[s] | loss 4.08
# | epoch 1 |  iter 21 / 351 | time 16[s] | loss 3.09
# | epoch 1 |  iter 41 / 351 | time 31[s] | loss 1.90
# | epoch 1 |  iter 61 / 351 | time 47[s] | loss 1.72
# | epoch 1 |  iter 81 / 351 | time 62[s] | loss 1.46
# | epoch 1 |  iter 101 / 351 | time 77[s] | loss 1.19
# | epoch 1 |  iter 121 / 351 | time 92[s] | loss 1.14
# | epoch 1 |  iter 141 / 351 | time 108[s] | loss 1.09
# | epoch 1 |  iter 161 / 351 | time 125[s] | loss 1.06
# | epoch 1 |  iter 181 / 351 | time 664[s] | loss 1.04
# | epoch 1 |  iter 201 / 351 | time 683[s] | loss 1.03
# | epoch 1 |  iter 221 / 351 | time 700[s] | loss 1.02
# | epoch 1 |  iter 241 / 351 | time 717[s] | loss 1.02
# | epoch 1 |  iter 261 / 351 | time 733[s] | loss 1.01
# | epoch 1 |  iter 281 / 351 | time 748[s] | loss 1.00
# | epoch 1 |  iter 301 / 351 | time 764[s] | loss 1.00
# | epoch 1 |  iter 321 / 351 | time 780[s] | loss 1.00
# | epoch 1 |  iter 341 / 351 | time 795[s] | loss 1.00
# Q 10/15/94
# T 1994-10-15
# ☒ 1978-08-11
# ---
# Q thursday, november 13, 2008
# T 2008-11-13
# ☒ 1978-08-11
# ---
# Q Mar 25, 2003
# T 2003-03-25
# ☒ 1978-08-11
# ---
# Q Tuesday, November 22, 2016
# T 2016-11-22
# ☒ 1978-08-11
# ---
# Q Saturday, July 18, 1970
# T 1970-07-18
# ☒ 1978-08-11
# ---
# Q october 6, 1992
# T 1992-10-06
# ☒ 1978-08-11
# ---
# Q 8/23/08
# T 2008-08-23
# ☒ 1978-08-11
# ---
# Q 8/30/07
# T 2007-08-30
# ☒ 1978-08-11
# ---
# Q 10/28/13
# T 2013-10-28
# ☒ 1978-08-11
# ---
# Q sunday, november 6, 2016
# T 2016-11-06
# ☒ 1978-08-11
# ---
# val acc 0.000%
# | epoch 2 |  iter 1 / 351 | time 0[s] | loss 1.00
# | epoch 2 |  iter 21 / 351 | time 15[s] | loss 1.00
# | epoch 2 |  iter 41 / 351 | time 33[s] | loss 0.99
# | epoch 2 |  iter 61 / 351 | time 50[s] | loss 0.99
# | epoch 2 |  iter 81 / 351 | time 68[s] | loss 0.99
# | epoch 2 |  iter 101 / 351 | time 87[s] | loss 0.99
# | epoch 2 |  iter 121 / 351 | time 104[s] | loss 0.99
# | epoch 2 |  iter 141 / 351 | time 122[s] | loss 0.98
# | epoch 2 |  iter 161 / 351 | time 141[s] | loss 0.98
# | epoch 2 |  iter 181 / 351 | time 157[s] | loss 0.97
# | epoch 2 |  iter 201 / 351 | time 173[s] | loss 0.95
# | epoch 2 |  iter 221 / 351 | time 189[s] | loss 0.94
# | epoch 2 |  iter 241 / 351 | time 205[s] | loss 0.90
# | epoch 2 |  iter 261 / 351 | time 220[s] | loss 0.83
# | epoch 2 |  iter 281 / 351 | time 235[s] | loss 0.74
# | epoch 2 |  iter 301 / 351 | time 252[s] | loss 0.66
# | epoch 2 |  iter 321 / 351 | time 269[s] | loss 0.58
# | epoch 2 |  iter 341 / 351 | time 285[s] | loss 0.46
# Q 10/15/94
# T 1994-10-15
# ☑ 1994-10-15
# ---
# Q thursday, november 13, 2008
# T 2008-11-13
# ☒ 2006-11-13
# ---
# Q Mar 25, 2003
# T 2003-03-25
# ☑ 2003-03-25
# ---
# Q Tuesday, November 22, 2016
# T 2016-11-22
# ☑ 2016-11-22
# ---
# Q Saturday, July 18, 1970
# T 1970-07-18
# ☑ 1970-07-18
# ---
# Q october 6, 1992
# T 1992-10-06
# ☑ 1992-10-06
# ---
# Q 8/23/08
# T 2008-08-23
# ☑ 2008-08-23
# ---
# Q 8/30/07
# T 2007-08-30
# ☒ 2007-08-09
# ---
# Q 10/28/13
# T 2013-10-28
# ☒ 1983-10-28
# ---
# Q sunday, november 6, 2016
# T 2016-11-06
# ☒ 2016-11-08
# ---
# val acc 51.640%
# | epoch 3 |  iter 1 / 351 | time 1[s] | loss 0.35
# | epoch 3 |  iter 21 / 351 | time 17[s] | loss 0.30
# | epoch 3 |  iter 41 / 351 | time 33[s] | loss 0.21
# | epoch 3 |  iter 61 / 351 | time 49[s] | loss 0.14
# | epoch 3 |  iter 81 / 351 | time 66[s] | loss 0.09
# | epoch 3 |  iter 101 / 351 | time 83[s] | loss 0.07
# | epoch 3 |  iter 121 / 351 | time 99[s] | loss 0.05
# | epoch 3 |  iter 141 / 351 | time 114[s] | loss 0.04
# | epoch 3 |  iter 161 / 351 | time 129[s] | loss 0.03
# | epoch 3 |  iter 181 / 351 | time 145[s] | loss 0.03
# | epoch 3 |  iter 201 / 351 | time 162[s] | loss 0.02
# | epoch 3 |  iter 221 / 351 | time 177[s] | loss 0.02
# | epoch 3 |  iter 241 / 351 | time 192[s] | loss 0.02
# | epoch 3 |  iter 261 / 351 | time 1128[s] | loss 0.01
# | epoch 3 |  iter 281 / 351 | time 1147[s] | loss 0.01
# | epoch 3 |  iter 301 / 351 | time 1163[s] | loss 0.01
# | epoch 3 |  iter 321 / 351 | time 1178[s] | loss 0.01
# | epoch 3 |  iter 341 / 351 | time 1193[s] | loss 0.01
# Q 10/15/94
# T 1994-10-15
# ☑ 1994-10-15
# ---
# Q thursday, november 13, 2008
# T 2008-11-13
# ☑ 2008-11-13
# ---
# Q Mar 25, 2003
# T 2003-03-25
# ☑ 2003-03-25
# ---
# Q Tuesday, November 22, 2016
# T 2016-11-22
# ☑ 2016-11-22
# ---
# Q Saturday, July 18, 1970
# T 1970-07-18
# ☑ 1970-07-18
# ---
# Q october 6, 1992
# T 1992-10-06
# ☑ 1992-10-06
# ---
# Q 8/23/08
# T 2008-08-23
# ☑ 2008-08-23
# ---
# Q 8/30/07
# T 2007-08-30
# ☑ 2007-08-30
# ---
# Q 10/28/13
# T 2013-10-28
# ☑ 2013-10-28
# ---
# Q sunday, november 6, 2016
# T 2016-11-06
# ☑ 2016-11-06
# ---
# val acc 99.900%
# | epoch 4 |  iter 1 / 351 | time 0[s] | loss 0.01
# | epoch 4 |  iter 21 / 351 | time 16[s] | loss 0.01
# | epoch 4 |  iter 41 / 351 | time 31[s] | loss 0.01
# | epoch 4 |  iter 61 / 351 | time 48[s] | loss 0.01
# | epoch 4 |  iter 81 / 351 | time 64[s] | loss 0.01
# | epoch 4 |  iter 101 / 351 | time 80[s] | loss 0.01
# | epoch 4 |  iter 121 / 351 | time 95[s] | loss 0.00
# | epoch 4 |  iter 141 / 351 | time 110[s] | loss 0.01
# | epoch 4 |  iter 161 / 351 | time 125[s] | loss 0.00
# | epoch 4 |  iter 181 / 351 | time 140[s] | loss 0.00
# | epoch 4 |  iter 201 / 351 | time 155[s] | loss 0.00
# | epoch 4 |  iter 221 / 351 | time 170[s] | loss 0.00
# | epoch 4 |  iter 241 / 351 | time 185[s] | loss 0.00
# | epoch 4 |  iter 261 / 351 | time 200[s] | loss 0.00
# | epoch 4 |  iter 281 / 351 | time 215[s] | loss 0.00
# | epoch 4 |  iter 301 / 351 | time 232[s] | loss 0.00
# | epoch 4 |  iter 321 / 351 | time 247[s] | loss 0.00
# | epoch 4 |  iter 341 / 351 | time 262[s] | loss 0.00
# Q 10/15/94
# T 1994-10-15
# ☑ 1994-10-15
# ---
# Q thursday, november 13, 2008
# T 2008-11-13
# ☑ 2008-11-13
# ---
# Q Mar 25, 2003
# T 2003-03-25
# ☑ 2003-03-25
# ---
# Q Tuesday, November 22, 2016
# T 2016-11-22
# ☑ 2016-11-22
# ---
# Q Saturday, July 18, 1970
# T 1970-07-18
# ☑ 1970-07-18
# ---
# Q october 6, 1992
# T 1992-10-06
# ☑ 1992-10-06
# ---
# Q 8/23/08
# T 2008-08-23
# ☑ 2008-08-23
# ---
# Q 8/30/07
# T 2007-08-30
# ☑ 2007-08-30
# ---
# Q 10/28/13
# T 2013-10-28
# ☑ 2013-10-28
# ---
# Q sunday, november 6, 2016
# T 2016-11-06
# ☑ 2016-11-06
# ---
# val acc 99.900%
# | epoch 5 |  iter 1 / 351 | time 0[s] | loss 0.00
# | epoch 5 |  iter 21 / 351 | time 17[s] | loss 0.00
# | epoch 5 |  iter 41 / 351 | time 1695[s] | loss 0.00
# | epoch 5 |  iter 61 / 351 | time 2260[s] | loss 0.00
# | epoch 5 |  iter 81 / 351 | time 4079[s] | loss 0.00
# | epoch 5 |  iter 101 / 351 | time 5072[s] | loss 0.00
# | epoch 5 |  iter 121 / 351 | time 6376[s] | loss 0.00
# | epoch 5 |  iter 141 / 351 | time 6394[s] | loss 0.00
# | epoch 5 |  iter 161 / 351 | time 6409[s] | loss 0.00
# | epoch 5 |  iter 181 / 351 | time 6424[s] | loss 0.00
# | epoch 5 |  iter 201 / 351 | time 6440[s] | loss 0.00
# | epoch 5 |  iter 221 / 351 | time 6461[s] | loss 0.00
# | epoch 5 |  iter 241 / 351 | time 6482[s] | loss 0.00
# | epoch 5 |  iter 261 / 351 | time 6497[s] | loss 0.00
# | epoch 5 |  iter 281 / 351 | time 6513[s] | loss 0.00
# | epoch 5 |  iter 301 / 351 | time 6529[s] | loss 0.00
# | epoch 5 |  iter 321 / 351 | time 6546[s] | loss 0.00
# | epoch 5 |  iter 341 / 351 | time 6563[s] | loss 0.00
# Q 10/15/94
# T 1994-10-15
# ☑ 1994-10-15
# ---
# Q thursday, november 13, 2008
# T 2008-11-13
# ☑ 2008-11-13
# ---
# Q Mar 25, 2003
# T 2003-03-25
# ☑ 2003-03-25
# ---
# Q Tuesday, November 22, 2016
# T 2016-11-22
# ☑ 2016-11-22
# ---
# Q Saturday, July 18, 1970
# T 1970-07-18
# ☑ 1970-07-18
# ---
# Q october 6, 1992
# T 1992-10-06
# ☑ 1992-10-06
# ---
# Q 8/23/08
# T 2008-08-23
# ☑ 2008-08-23
# ---
# Q 8/30/07
# T 2007-08-30
# ☑ 2007-08-30
# ---
# Q 10/28/13
# T 2013-10-28
# ☑ 2013-10-28
# ---
# Q sunday, november 6, 2016
# T 2016-11-06
# ☑ 2016-11-06
# ---
# val acc 99.920%
# | epoch 6 |  iter 1 / 351 | time 1[s] | loss 0.00
# | epoch 6 |  iter 21 / 351 | time 18[s] | loss 0.00
# | epoch 6 |  iter 41 / 351 | time 34[s] | loss 0.00
# | epoch 6 |  iter 61 / 351 | time 49[s] | loss 0.00
# | epoch 6 |  iter 81 / 351 | time 64[s] | loss 0.00
# | epoch 6 |  iter 101 / 351 | time 79[s] | loss 0.00
# | epoch 6 |  iter 121 / 351 | time 94[s] | loss 0.00
# | epoch 6 |  iter 141 / 351 | time 113[s] | loss 0.00
# | epoch 6 |  iter 161 / 351 | time 129[s] | loss 0.00
# | epoch 6 |  iter 181 / 351 | time 145[s] | loss 0.00
# | epoch 6 |  iter 201 / 351 | time 161[s] | loss 0.00
# | epoch 6 |  iter 221 / 351 | time 177[s] | loss 0.00
# | epoch 6 |  iter 241 / 351 | time 193[s] | loss 0.00
# | epoch 6 |  iter 261 / 351 | time 218[s] | loss 0.00
# | epoch 6 |  iter 281 / 351 | time 236[s] | loss 0.00
# | epoch 6 |  iter 301 / 351 | time 251[s] | loss 0.00
# | epoch 6 |  iter 321 / 351 | time 267[s] | loss 0.00
# | epoch 6 |  iter 341 / 351 | time 282[s] | loss 0.00
# Q 10/15/94
# T 1994-10-15
# ☑ 1994-10-15
# ---
# Q thursday, november 13, 2008
# T 2008-11-13
# ☑ 2008-11-13
# ---
# Q Mar 25, 2003
# T 2003-03-25
# ☑ 2003-03-25
# ---
# Q Tuesday, November 22, 2016
# T 2016-11-22
# ☑ 2016-11-22
# ---
# Q Saturday, July 18, 1970
# T 1970-07-18
# ☑ 1970-07-18
# ---
# Q october 6, 1992
# T 1992-10-06
# ☑ 1992-10-06
# ---
# Q 8/23/08
# T 2008-08-23
# ☑ 2008-08-23
# ---
# Q 8/30/07
# T 2007-08-30
# ☑ 2007-08-30
# ---
# Q 10/28/13
# T 2013-10-28
# ☑ 2013-10-28
# ---
# Q sunday, november 6, 2016
# T 2016-11-06
# ☑ 2016-11-06
# ---
# val acc 99.920%
# | epoch 7 |  iter 1 / 351 | time 0[s] | loss 0.00
# | epoch 7 |  iter 21 / 351 | time 16[s] | loss 0.00
# | epoch 7 |  iter 41 / 351 | time 31[s] | loss 0.00
# | epoch 7 |  iter 61 / 351 | time 46[s] | loss 0.02
# | epoch 7 |  iter 81 / 351 | time 61[s] | loss 0.01
# | epoch 7 |  iter 101 / 351 | time 76[s] | loss 0.01
# | epoch 7 |  iter 121 / 351 | time 91[s] | loss 0.00
# | epoch 7 |  iter 141 / 351 | time 106[s] | loss 0.00
# | epoch 7 |  iter 161 / 351 | time 121[s] | loss 0.00
# | epoch 7 |  iter 181 / 351 | time 966[s] | loss 0.00
# | epoch 7 |  iter 201 / 351 | time 984[s] | loss 0.00
# | epoch 7 |  iter 221 / 351 | time 999[s] | loss 0.00
# | epoch 7 |  iter 241 / 351 | time 1015[s] | loss 0.00
# | epoch 7 |  iter 261 / 351 | time 1030[s] | loss 0.00
# | epoch 7 |  iter 281 / 351 | time 1045[s] | loss 0.00
# | epoch 7 |  iter 301 / 351 | time 1059[s] | loss 0.00
# | epoch 7 |  iter 321 / 351 | time 1074[s] | loss 0.00
# | epoch 7 |  iter 341 / 351 | time 1089[s] | loss 0.00
# Q 10/15/94
# T 1994-10-15
# ☑ 1994-10-15
# ---
# Q thursday, november 13, 2008
# T 2008-11-13
# ☑ 2008-11-13
# ---
# Q Mar 25, 2003
# T 2003-03-25
# ☑ 2003-03-25
# ---
# Q Tuesday, November 22, 2016
# T 2016-11-22
# ☑ 2016-11-22
# ---
# Q Saturday, July 18, 1970
# T 1970-07-18
# ☑ 1970-07-18
# ---
# Q october 6, 1992
# T 1992-10-06
# ☑ 1992-10-06
# ---
# Q 8/23/08
# T 2008-08-23
# ☑ 2008-08-23
# ---
# Q 8/30/07
# T 2007-08-30
# ☑ 2007-08-30
# ---
# Q 10/28/13
# T 2013-10-28
# ☑ 2013-10-28
# ---
# Q sunday, november 6, 2016
# T 2016-11-06
# ☑ 2016-11-06
# ---
# val acc 99.960%
# | epoch 8 |  iter 1 / 351 | time 0[s] | loss 0.00
# | epoch 8 |  iter 21 / 351 | time 15[s] | loss 0.00
# | epoch 8 |  iter 41 / 351 | time 34[s] | loss 0.00
# | epoch 8 |  iter 61 / 351 | time 50[s] | loss 0.00
# | epoch 8 |  iter 81 / 351 | time 67[s] | loss 0.00
# | epoch 8 |  iter 101 / 351 | time 82[s] | loss 0.00
# | epoch 8 |  iter 121 / 351 | time 98[s] | loss 0.00
# | epoch 8 |  iter 141 / 351 | time 114[s] | loss 0.00
# | epoch 8 |  iter 161 / 351 | time 132[s] | loss 0.00
# | epoch 8 |  iter 181 / 351 | time 3121[s] | loss 0.00
# | epoch 8 |  iter 201 / 351 | time 4987[s] | loss 0.00
# | epoch 8 |  iter 221 / 351 | time 6629[s] | loss 0.00
# | epoch 8 |  iter 241 / 351 | time 7312[s] | loss 0.00
# | epoch 8 |  iter 261 / 351 | time 7328[s] | loss 0.00
# | epoch 8 |  iter 281 / 351 | time 7351[s] | loss 0.00
# | epoch 8 |  iter 301 / 351 | time 7368[s] | loss 0.00
# | epoch 8 |  iter 321 / 351 | time 7385[s] | loss 0.00
# | epoch 8 |  iter 341 / 351 | time 7402[s] | loss 0.00
# Q 10/15/94
# T 1994-10-15
# ☑ 1994-10-15
# ---
# Q thursday, november 13, 2008
# T 2008-11-13
# ☑ 2008-11-13
# ---
# Q Mar 25, 2003
# T 2003-03-25
# ☑ 2003-03-25
# ---
# Q Tuesday, November 22, 2016
# T 2016-11-22
# ☑ 2016-11-22
# ---
# Q Saturday, July 18, 1970
# T 1970-07-18
# ☑ 1970-07-18
# ---
# Q october 6, 1992
# T 1992-10-06
# ☑ 1992-10-06
# ---
# Q 8/23/08
# T 2008-08-23
# ☑ 2008-08-23
# ---
# Q 8/30/07
# T 2007-08-30
# ☑ 2007-08-30
# ---
# Q 10/28/13
# T 2013-10-28
# ☑ 2013-10-28
# ---
# Q sunday, november 6, 2016
# T 2016-11-06
# ☑ 2016-11-06
# ---
# val acc 99.960%
# | epoch 9 |  iter 1 / 351 | time 0[s] | loss 0.00
# | epoch 9 |  iter 21 / 351 | time 17[s] | loss 0.00
# | epoch 9 |  iter 41 / 351 | time 33[s] | loss 0.00
# | epoch 9 |  iter 61 / 351 | time 49[s] | loss 0.00
# | epoch 9 |  iter 81 / 351 | time 64[s] | loss 0.00
# | epoch 9 |  iter 101 / 351 | time 80[s] | loss 0.00
# | epoch 9 |  iter 121 / 351 | time 95[s] | loss 0.00
# | epoch 9 |  iter 141 / 351 | time 111[s] | loss 0.00
# | epoch 9 |  iter 161 / 351 | time 126[s] | loss 0.00
# | epoch 9 |  iter 181 / 351 | time 144[s] | loss 0.00
# | epoch 9 |  iter 201 / 351 | time 162[s] | loss 0.00
# | epoch 9 |  iter 221 / 351 | time 178[s] | loss 0.00
# | epoch 9 |  iter 241 / 351 | time 196[s] | loss 0.00
# | epoch 9 |  iter 261 / 351 | time 213[s] | loss 0.00
# | epoch 9 |  iter 281 / 351 | time 230[s] | loss 0.00
# | epoch 9 |  iter 301 / 351 | time 252[s] | loss 0.00
# | epoch 9 |  iter 321 / 351 | time 270[s] | loss 0.00
# | epoch 9 |  iter 341 / 351 | time 288[s] | loss 0.00
# Q 10/15/94
# T 1994-10-15
# ☑ 1994-10-15
# ---
# Q thursday, november 13, 2008
# T 2008-11-13
# ☑ 2008-11-13
# ---
# Q Mar 25, 2003
# T 2003-03-25
# ☑ 2003-03-25
# ---
# Q Tuesday, November 22, 2016
# T 2016-11-22
# ☑ 2016-11-22
# ---
# Q Saturday, July 18, 1970
# T 1970-07-18
# ☑ 1970-07-18
# ---
# Q october 6, 1992
# T 1992-10-06
# ☑ 1992-10-06
# ---
# Q 8/23/08
# T 2008-08-23
# ☑ 2008-08-23
# ---
# Q 8/30/07
# T 2007-08-30
# ☑ 2007-08-30
# ---
# Q 10/28/13
# T 2013-10-28
# ☑ 2013-10-28
# ---
# Q sunday, november 6, 2016
# T 2016-11-06
# ☑ 2016-11-06
# ---
# val acc 99.960%
# | epoch 10 |  iter 1 / 351 | time 0[s] | loss 0.00
# | epoch 10 |  iter 21 / 351 | time 17[s] | loss 0.00
# | epoch 10 |  iter 41 / 351 | time 35[s] | loss 0.00
# | epoch 10 |  iter 61 / 351 | time 52[s] | loss 0.00
# | epoch 10 |  iter 81 / 351 | time 68[s] | loss 0.00
# | epoch 10 |  iter 101 / 351 | time 86[s] | loss 0.00
# | epoch 10 |  iter 121 / 351 | time 102[s] | loss 0.00
# | epoch 10 |  iter 141 / 351 | time 119[s] | loss 0.00
# | epoch 10 |  iter 161 / 351 | time 136[s] | loss 0.00
# | epoch 10 |  iter 181 / 351 | time 153[s] | loss 0.00
# | epoch 10 |  iter 201 / 351 | time 174[s] | loss 0.00
# | epoch 10 |  iter 221 / 351 | time 2171[s] | loss 0.00
# | epoch 10 |  iter 241 / 351 | time 2190[s] | loss 0.00
# | epoch 10 |  iter 261 / 351 | time 2209[s] | loss 0.00
# | epoch 10 |  iter 281 / 351 | time 2226[s] | loss 0.00
# | epoch 10 |  iter 301 / 351 | time 2243[s] | loss 0.00
# | epoch 10 |  iter 321 / 351 | time 2260[s] | loss 0.00
# | epoch 10 |  iter 341 / 351 | time 2277[s] | loss 0.00
# Q 10/15/94
# T 1994-10-15
# ☑ 1994-10-15
# ---
# Q thursday, november 13, 2008
# T 2008-11-13
# ☑ 2008-11-13
# ---
# Q Mar 25, 2003
# T 2003-03-25
# ☑ 2003-03-25
# ---
# Q Tuesday, November 22, 2016
# T 2016-11-22
# ☑ 2016-11-22
# ---
# Q Saturday, July 18, 1970
# T 1970-07-18
# ☑ 1970-07-18
# ---
# Q october 6, 1992
# T 1992-10-06
# ☑ 1992-10-06
# ---
# Q 8/23/08
# T 2008-08-23
# ☑ 2008-08-23
# ---
# Q 8/30/07
# T 2007-08-30
# ☑ 2007-08-30
# ---
# Q 10/28/13
# T 2013-10-28
# ☑ 2013-10-28
# ---
# Q sunday, november 6, 2016
# T 2016-11-06
# ☑ 2016-11-06
# ---
# val acc 99.960%
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-40e27ed8d599> in <module>
#      20
#      21 x = np.arange(len(acc_list))
# ---> 22 plt.plot(x, acc_list, marker='o')
#      23 plt.xlabel('epochs')
#      24 plt.ylabel('accuracy')
#
# NameError: name 'plt' is not defined
