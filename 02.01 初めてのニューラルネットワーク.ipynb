# %% [markdown]
# ## 2.1　初めてのニューラルネットワーク

# %%
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.datasets import mnist

# %%
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

# %%
print(train_images.shape)
print(train_labels.shape)
print(test_images.shape)
print(test_labels.shape)
# Out:
# (60000, 28, 28)
# (60000,)
# (10000, 28, 28)
# (10000,)

# %%
model = keras.Sequential([
    layers.Dense(512, activation='relu'),
    layers.Dense(10, activation='softmax')
])

# %% [markdown]
# `Dense` 層は、全結合層のことである。

# %%
model.compile(
    optimizer='rmsprop',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
    )

# %%
train_images = train_images.reshape((60000, 28 * 28))
train_images = train_images.astype('float32') / 255
test_images = test_images.reshape((10000, 28*28))
test_images = test_images.astype('float32') / 255
print(train_images.shape)
print(test_images.shape)
# Out:
# (60000, 784)
# (10000, 784)

# %%
model.fit(train_images, train_labels, epochs=5, batch_size=128)
# Out:
# Epoch 1/5
# 469/469 [==============================] - 8s 16ms/step - loss: 0.2614 - accuracy: 0.9250
# Epoch 2/5
# 469/469 [==============================] - 5s 10ms/step - loss: 0.1054 - accuracy: 0.9694
# Epoch 3/5
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0700 - accuracy: 0.9794
# Epoch 4/5
# 469/469 [==============================] - 6s 12ms/step - loss: 0.0498 - accuracy: 0.9853
# Epoch 5/5
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0378 - accuracy: 0.9886

# %%
test_digits = test_images[0:10]
predictions = model.predict(test_digits)
print(predictions[0])
print(predictions[0].argmax())
print(predictions[0][7])
print(test_labels[0])
# Out:
# 1/1 [==============================] - 0s 265ms/step
# [1.3208987e-07 1.9314793e-08 1.5643753e-05 6.9999536e-05 8.8945913e-11
#  3.5700456e-08 2.6728407e-12 9.9991161e-01 1.4084628e-06 1.2518972e-06]
# 7
# 0.9999116
# 7

# %%
test_loss, test_acc = model.evaluate(test_images, test_labels)
print(f'test_acc: {test_acc}')
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0654 - accuracy: 0.9787
# test_acc: 0.9786999821662903
