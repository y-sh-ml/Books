# %% [markdown]
# ## 1.3　「合成関数」と Python での実装

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def f(x):
  return (2 * x**2 + 2)

# %%
x = np.arange(-2, 2.1, 0.25)
print(x)
# Out:
# [-2.   -1.75 -1.5  -1.25 -1.   -0.75 -0.5  -0.25  0.    0.25  0.5   0.75
#   1.    1.25  1.5   1.75  2.  ]

# %%
y = f(x)
print(y)
# Out:
# [10.     8.125  6.5    5.125  4.     3.125  2.5    2.125  2.     2.125
#   2.5    3.125  4.     5.125  6.5    8.125 10.   ]

# %%
plt.figure(figsize=(5, 3))
plt.plot(x, y)

# %%
def f1(x):
  return (x**2)

def f2(x):
  return(x*2)

def f3(x):
  return (x+2)

x1 = f1(x)
x2 = f2(x1)
x3 = f3(x2)
